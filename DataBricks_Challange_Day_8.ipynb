# %%
# %sql
CREATE CATALOG IF NOT EXISTS day8_catalog;

# %%
# %sql
USE CATALOG day8_catalog;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS ecommerce;

# %%
# %sql
USE SCHEMA ecommerce;

# %%
# %sql
CREATE TABLE IF NOT EXISTS events_silver
USING DELTA
AS
SELECT *
FROM delta.`/Volumes/workspace/ecommerce/ecommerce_data/medallion/silver/events`;

# %%
# %sql
SHOW TABLES;

# %%
# %sql
DESCRIBE DETAIL events_silver;

# %%
# %sql
CREATE OR REPLACE VIEW day8_catalog.ecommerce.events_public_view AS
SELECT
    event_time,
    event_type,
    product_id,
    category_code,
    brand,
    price
FROM day8_catalog.ecommerce.events_silver;

# %%
# %sql
USE CATALOG day8_catalog;

# %%
# %sql
USE SCHEMA ecommerce;

# %%
# %sql
CREATE OR REPLACE VIEW events_public_view AS
SELECT
    event_time,
    event_type,
    product_id,
    category_code,
    brand,
    price
FROM events_silver;

# %%
# %sql
SHOW TABLES IN day8_catalog.ecommerce;

# %%
import mlflow

with mlflow.start_run(run_name="day14_ai_powered_analytics"):
    mlflow.log_param("ai_tool", "Databricks Mosaic AI (conceptual)")
    mlflow.log_param("task", "sentiment analysis / genai exploration")
    mlflow.log_metric("example_score", 0.95)

# %%
# %pip install transformers torch

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis")
classifier(["Great product", "Worst purchase"])

# %%
import mlflow

reviews = [
    {"text": "Amazing product", "sentiment": "POSITIVE"},
    {"text": "Bad quality", "sentiment": "NEGATIVE"}
]

with mlflow.start_run(run_name="day14_ai_simulation"):
    mlflow.log_param("model", "genai-simulation")
    mlflow.log_param("tool", "Databricks Mosaic AI")
    mlflow.log_metric("positive_reviews", 1)
    mlflow.log_metric("negative_reviews", 1)

reviews
